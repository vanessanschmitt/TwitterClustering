# %%
# %load_ext sql
# %sql sqlite:///followers.db
# Out:
# /Users/vanessafriedemann/Library/Python/2.7/lib/python/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /Users/vanessafriedemann/Library/Python/2.7/lib/python/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# u'Connected: None@followers.db'

# %%
influencer = '@NASA'
filename = 'influencer_' + influencer.replace('@','') +'.txt'

with open(filename,'r') as f_in:
    for line in f_in: 
        line = line.rstrip()
        pieces = line.split(' ')
        id = pieces[3].split('=')[1]
        following = int(pieces[4].split('=')[1] == 'True')
        print id,following
        try: 
            # %sql INSERT INTO Influencers (FollowerID, InfluencerName, Following) VALUES (:id, :influencer, :following);
        except:
            print 'failed'
            continue
# Out:
# 458977683 0
# 1 rows affected.
# 4197454515 0
# 1 rows affected.
# 93080767 0
# 1 rows affected.
# 4222265832 0
# 1 rows affected.
# 3249250893 0
# 1 rows affected.
# 1476964476 0
# 1 rows affected.
# 91756612 0
# 1 rows affected.
# 3023825365 0
# 1 rows affected.
# 456993297 0
# 1 rows affected.
# 1516949503 0
# 1 rows affected.
# 3040277234 0
# 1 rows affected.
# 328945115 0
# 1 rows affected.
# 4225191558 0
# 1 rows affected.
# 3876653366 0
# 1 rows affected.
# 3606495681 0
# 1 rows affected.
# 1382421882 0
# 1 rows affected.
# 3374935769 0
# 1 rows affected.
# 920129395 0
# 1 rows affected.
# 4237032380 0
# 1 rows affected.
# 4179362663 0
# 1 rows affected.
# 4138184261 0
# 1 rows affected.
# 4179161021 0
# 1 rows affected.
# 3310100678 0
# 1 rows affected.
# 183222594 0
# 1 rows affected.
# 784948694 0
# 1 rows affected.
# 3241428076 0
# 1 rows affected.
# 3246523285 0
# 1 rows affected.
# 248299802 1
# 1 rows affected.
# 483018613 0
# 1 rows affected.
# 4186318205 0
# ...
